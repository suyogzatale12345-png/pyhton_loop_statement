# %% [markdown]
# # .keys loop

# %%
student = {
    "name": "Suyog",
    "age": 21,
    "course": "IT"
}


for stud in student.values():
    print(f"stud = {stud}, type of stud = {type(stud)} keyVaue ={student.get(stud)}")
# Out:
# stud = Suyog, type of stud = <class 'str'> keyVaue =None
# stud = 21, type of stud = <class 'int'> keyVaue =None
# stud = IT, type of stud = <class 'str'> keyVaue =None
