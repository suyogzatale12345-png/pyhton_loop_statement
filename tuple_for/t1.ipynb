# %%
tdata1 = ('a','b','c')

print(f"tdata1 = {tdata1}, type of tdata1 = {type(tdata1)} len of tdata1 = {len(tdata1)}")
# Out:
# tdata1 = ('a', 'b', 'c'), type of tdata1 = <class 'tuple'> len of tdata1 = 3

# %%
print(f"tdata1[0] = {tdata1[0]} type of tdata1 = {type(tdata1[0])}")
print(f"tdata1[1] = {tdata1[1]} type of tdata1 = {type(tdata1[1])}")
print(f"tdata1[2] = {tdata1[2]} type of tdata1 = {type(tdata1[2])}")
print(f"tdata1[3] = {tdata1[3]} type of tdata1 = {type(tdata1[3])}")
# Out:
# tdata1[0] = a type of tdata1 = <class 'str'>
# tdata1[1] = b type of tdata1 = <class 'str'>
# tdata1[2] = c type of tdata1 = <class 'str'>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 4
#       2 print(f"tdata1[1] = {tdata1[1]} type of tdata1 = {type(tdata1[1])}")
#       3 print(f"tdata1[2] = {tdata1[2]} type of tdata1 = {type(tdata1[2])}")
# ----> 4 print(f"tdata1[3] = {tdata1[3]} type of tdata1 = {type(tdata1[3])}")
#
# IndexError: tuple index out of range

# %%
print(f"tdata1[0] = {tdata1[0]} before change")

tdata1[0] = 'new value'

print(f"tdata1[0] = {tdata1[0]} after change")
# Out:
# tdata1[0] = a before change
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 print(f"tdata1[0] = {tdata1[0]} before change")
# ----> 3 tdata1[0] = 'new value'
#       5 print(f"tdata1[0] = {tdata1[0]} after change")
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(tdata1[0:1])
print(tdata1[-1])
# Out:
# ('a',)
# c

# %%
tdata1 = 'complete change'
print(tdata1)
# Out:
# complete change

# %%
tdata2 = ('g',1,{"name": "arc"}, [1,2,3])

print(tdata2[2].get('name'))
# Out:
# arc

# %%
print(type(tdata2))

tdata = list(tdata2)

print(type(tdata2))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
tdata3 = {'a','b','c','a'}

print(tdata3)
# Out:
# {'a', 'c', 'b'}

# %%
tdata1[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 tdata1[0]
#
# NameError: name 'tdata1' is not defined

# %%
for v in tdata3:
    print(v)
# Out:
# a
# c
# b

# %%
tdata3 .add("new value")

for v in tdata3:
    print(v)
# Out:
# new value
# a
# c
# b

# %%
tdata3.remove("new value")   # Error if not found
tdata3.discard("apple")  # No error if not found
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 tdata3.remove("new value")   # Error if not found
#       2 tdata3.discard("apple")  # No error if not found
#
# KeyError: 'new value'

# %%
s1 = {1,2,3,3,8}
s2 = {1,2,3,5,8}

print(f"union = {s1 | s2}")
print(f"intersect = {s1 & s2}")
print(f"Deffernce = {s1 - s2}")
print(f"Deffernce = {s2 - s1}")
# Out:
# union = {1, 2, 3, 5, 8}
# intersect = {8, 1, 2, 3}
# Deffernce = set()
# Deffernce = {5}

# %%
fs = frozenset([1,2,3,6,1])

print(type(fs),fs)
# Out:
# <class 'frozenset'> frozenset({1, 2, 3, 6})
